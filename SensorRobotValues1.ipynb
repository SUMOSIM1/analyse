# %% [markdown]
# # Sensor and Robot control parameters
# Two 'Clever I' controller playing against each other

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/t1.csv", sep=";")

# %%
df
# Out:
#      A_distLeft  A_distCenter  A_distRight A_opponent  A_rotRight  A_rotLeft  \
# 0        337.05        462.55       309.89      UNDEF        29.0       20.0
# 1        294.11        473.33       377.69      UNDEF        26.0       22.0
# 2        238.76        380.64       399.70      UNDEF        26.0       21.0
# 3        302.02        366.02       399.59      UNDEF        20.0       25.0
# 4        254.92        354.23       332.43      UNDEF        25.0       25.0
# ..          ...           ...          ...        ...         ...        ...
# 140      224.53        586.58       233.42     CENTER        24.0       24.0
# 141      237.15        552.74       153.51       LEFT        26.0       25.0
# 142      206.76        580.29       135.69      UNDEF        28.0       25.0
# 143      137.83        546.36       113.19      UNDEF        26.0       21.0
# 144      132.54        557.42       178.33      UNDEF        23.0       25.0
#
# ...

# %%
df[['A_distLeft', 'A_distRight', 'A_distCenter']].plot()
# Out:
# <Axes: >

# %%
df[['B_distLeft', 'B_distRight', 'B_distCenter']].plot()
# Out:
# <Axes: >

# %%
df.keys()
# Out:
# Index(['A_distLeft', 'A_distCenter', 'A_distRight', 'A_opponent', 'A_rotRight',
#        'A_rotLeft', 'B_distLeft', 'B_distCenter', 'B_distRight', 'B_opponent',
#        'B_rotRight', 'B_rotLeft'],
#       dtype='object')

# %%
df[["A_rotLeft", "A_rotRight"]].plot()
# Out:
# <Axes: >

# %%
df[["A_rotLeft", "A_rotRight"]].plot()
# Out:
# <Axes: >

# %%
df[["B_rotLeft", "B_rotRight"]].plot()
# Out:
# <Axes: >

# %%
df[['A_opponent', 'A_rotLeft']].groupby(['A_opponent']).count()
# Out:
#             A_rotLeft
# A_opponent
# CENTER              2
# LEFT                2
# RIGHT               3
# UNDEF             138

# %%
df[['B_opponent', 'B_rotLeft']].groupby(['B_opponent']).count()
# Out:
#             B_rotLeft
# B_opponent
# LEFT                1
# RIGHT               2
# UNDEF             142
